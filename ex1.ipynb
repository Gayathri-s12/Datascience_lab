# %% [markdown]
# <a href="https://colab.research.google.com/github/Gayathri-s12/Datascience_lab/blob/main/ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Experiment Title: Simulation of Scalable Data Pipeline
Stages: Ingestion -> Processing -> Output
Technology: Python (Threading, Queue, Pandas)

Aim:
To design and simulate a scalable data pipeline that performs real-time data ingestion, processing, and storage using Python.

Description :
This experiment demonstrates a multi-stage data pipeline consisting of ingestion, processing, and output stages.
The ingestion stage simulates real-time sensor data generation using random values.
The processing stage cleans and transforms the data by applying conditions and adding status labels.
The output stage collects the processed data and stores it in a structured CSV file using Pandas.
Python threading is used to execute each stage concurrently, improving efficiency and scalability.
Queues are used for safe data transfer between stages.
This model represents how modern data pipelines handle streaming data in real-world applications.


"""

import threading
import queue
import random
import time
import pandas as pd

# Create shared queues
ingestion_queue = queue.Queue()
processing_queue = queue.Queue()

# ----------- STAGE 1: DATA INGESTION -----------
def data_ingestion():
    """
    Simulates streaming data ingestion from sensors
    """
    for i in range(100):   # simulate 100 records
        data = {
            "sensor_id": random.randint(1, 5),
            "temperature": random.uniform(20, 40),
            "humidity": random.uniform(30, 90),
            "timestamp": time.time()
        }
        ingestion_queue.put(data)
        print(f"Ingested: {data}")
        time.sleep(0.05)   # simulate real-time delay

    ingestion_queue.put(None)  # signal completion


# ----------- STAGE 2: DATA PROCESSING -----------
def data_processing():
    """
    Cleans and transforms incoming data
    """
    while True:
        data = ingestion_queue.get()

        if data is None:
            processing_queue.put(None)
            break

        # Data cleaning
        if data["temperature"] > 25:
            data["status"] = "HIGH"
        else:
            data["status"] = "NORMAL"

        processing_queue.put(data)
        print(f"Processed: {data}")


# ----------- STAGE 3: DATA OUTPUT -----------
def data_output():
    """
    Stores processed data into CSV file
    """
    processed_data = []

    while True:
        data = processing_queue.get()

        if data is None:
            break

        processed_data.append(data)
        print(f"Output Ready: {data}")

    # Save to CSV
    df = pd.DataFrame(processed_data)
    df.to_csv("processed_sensor_data.csv", index=False)
    print("\nData successfully saved to processed_sensor_data.csv")


# ----------- MAIN EXECUTION -----------
if __name__ == "__main__":
    t1 = threading.Thread(target=data_ingestion)
    t2 = threading.Thread(target=data_processing)
    t3 = threading.Thread(target=data_output)

    t1.start()
    t2.start()
    t3.start()

    t1.join()
    t2.join()
    t3.join()

    print("\nPipeline Execution Completed Successfully!")
# Out:
# Ingested: {'sensor_id': 2, 'temperature': 39.714874866431174, 'humidity': 40.744045359593486, 'timestamp': 1777436011.9372945}
# Processed: {'sensor_id': 2, 'temperature': 39.714874866431174, 'humidity': 40.744045359593486, 'timestamp': 1777436011.9372945, 'status': 'HIGH'}
# Output Ready: {'sensor_id': 2, 'temperature': 39.714874866431174, 'humidity': 40.744045359593486, 'timestamp': 1777436011.9372945, 'status': 'HIGH'}
# Ingested: {'sensor_id': 4, 'temperature': 36.530798516145026, 'humidity': 81.16912363851219, 'timestamp': 1777436011.9877484}
# Processed: {'sensor_id': 4, 'temperature': 36.530798516145026, 'humidity': 81.16912363851219, 'timestamp': 1777436011.9877484, 'status': 'HIGH'}
# Output Ready: {'sensor_id': 4, 'temperature': 36.530798516145026, 'humidity': 81.16912363851219, 'timestamp': 1777436011.9877484, 'status': 'HIGH'}
# Ingested: {'sensor_id': 2, 'temperature': 22.87280988800432, 'humidity': 89.28109946448717, 'timestamp': 1777436012.0380008}
# ...
